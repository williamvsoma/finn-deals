# %%
# %load_ext autoreload
# %autoreload 2

# %%
from finn_deals.scraping.finn import FinnAPI

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
api = FinnAPI()

# %%
df = api.search_dataframe(query="gitar")
df
# Out:
#              id                                              title  \
# 0     441498743    Aria  Akustisk gitar stålstrenger Made in Japan
# 1     441482616                              Østbu gitar modell 6P
# 2     441411190                                   Morgan gitar 1/2
# 3     441482662                                   Klassisk gitar 🎸
# 4     441472735          Taylor 416ce-LTD Baritone, akustisk gitar
# ...         ...                                                ...
# 2645  430145791  Julegave? Byttes/selges! Gibson SG USA 50th An...
# 2646  380217165        Gibson Memphis ES-335 Sixties Cherry (2016)
# 2647  340882260                          Yamaha LL56 Custom A.R.E.
# 2648  440124857  Julegave til gitaristen? Gibson Custom Memphis...
# 2649  440057592                          Cort masterclass series 1
#
#                                                     url       location  \
# 0     https://www.finn.no/recommerce/forsale/item/44...          Sætre
# 1     https://www.finn.no/bap/webstore/ad.html?finnk...         Gjøvik
# 2     https://www.finn.no/recommerce/forsale/item/44...  Fyllingsdalen
# 3     https://www.finn.no/recommerce/forsale/item/44...      Hunndalen
# 4     https://www.finn.no/recommerce/forsale/item/44...          Skien
# ...                                                 ...            ...
# 2645  https://www.finn.no/recommerce/forsale/item/43...        Farsund
# 2646  https://www.finn.no/recommerce/forsale/item/38...           Oslo
# 2647  https://www.finn.no/recommerce/forsale/item/34...         Øvrebø
# 2648  https://www.finn.no/recommerce/forsale/item/44...        Farsund
# 2649  https://www.finn.no/recommerce/forsale/item/44...          Sætre
#
#       price_amount price_currency price_unit price_display  \
# 0              900            NOK         kr        900 kr
# 1             5500            NOK         kr       5500 kr
# 2              750            NOK         kr        750 kr
# 3             4000            NOK         kr       4000 kr
# 4            17000            NOK         kr      17000 kr
# ...            ...            ...        ...           ...
# 2645         18500            NOK         kr      18500 kr
# 2646         35000            NOK         kr      35000 kr
# 2647         78000            NOK         kr      78000 kr
# 2648         65000            NOK         kr      65000 kr
# 2649          6500            NOK         kr       6500 kr
#
#                                               image_url  \
# 0     https://images.finncdn.no/dynamic/default/item...
# 1     https://images.finncdn.no/dynamic/default/2025...
# 2     https://images.finncdn.no/dynamic/default/item...
# 3     https://images.finncdn.no/dynamic/default/item...
# 4     https://images.finncdn.no/dynamic/default/item...
# ...                                                 ...
# 2645  https://images.finncdn.no/dynamic/default/item...
# 2646  https://images.finncdn.no/dynamic/default/2024...
# 2647  https://images.finncdn.no/dynamic/default/2024...
# 2648  https://images.finncdn.no/dynamic/default/item...
# 2649  https://images.finncdn.no/dynamic/default/item...
#
#                              timestamp
# 0            2025-12-11T18:35:18+00:00
# 1     2025-12-11T16:18:29.141000+00:00
# 2            2025-12-11T18:24:24+00:00
# 3            2025-12-11T16:36:56+00:00
# 4            2025-12-11T15:40:50+00:00
# ...                                ...
# 2645         2025-12-02T19:47:08+00:00
# 2646         2025-12-02T13:33:32+00:00
# 2647         2025-12-02T13:33:32+00:00
# 2648         2025-12-02T19:43:01+00:00
# 2649         2025-12-02T13:11:29+00:00
#
# [2650 rows x 10 columns]

# %%
df_test = api.search_dataframe_sharded(query="gitar")
df_test # I DID A THING!!!!
# Out:
#              id                                              title  \
# 0     441478900                                    Gitar til salgs
# 1      43247649                          Mikrofonvendere for gitar
# 2     441505573  Snark sn-1 sn1 gitar tuner i pent tilstand selges
# 3     441476672                               Capo for gitar i tre
# 4     441428375                                         Gitar barn
# ...         ...                                                ...
# 7898  435993993  Nesten ny Martin D-42 Special med LR Bag Antem...
# 7899  435083029  Martin D-42 Modern Deluxe Custom - Adirondack ...
# 7900  434831513                                             Som ny
# 7901  297962570                                Martin D18 fra 1946
# 7902  440999526       Gibson Les Paul Custom 1957 m/original kasse
#
#                                                     url        location  \
# 0     https://www.finn.no/recommerce/forsale/item/44...    Borgenhaugen
# 1     https://www.finn.no/bap/webstore/ad.html?finnk...      Hundeidvik
# 2     https://www.finn.no/recommerce/forsale/item/44...     Blommenholm
# 3     https://www.finn.no/recommerce/forsale/item/44...            Oslo
# 4     https://www.finn.no/recommerce/forsale/item/44...       Ytre Arna
# ...                                                 ...             ...
# 7898  https://www.finn.no/recommerce/forsale/item/43...  Kristiansand S
# 7899  https://www.finn.no/recommerce/forsale/item/43...  Kristiansand S
# 7900  https://www.finn.no/recommerce/forsale/item/43...    Nordkjosbotn
# 7901  https://www.finn.no/recommerce/forsale/item/29...       Arnatveit
# 7902  https://www.finn.no/recommerce/forsale/item/44...            Oslo
#
#       price_amount price_currency price_unit price_display  \
# 0              200            NOK         kr        200 kr
# 1              105            NOK         kr        105 kr
# 2              150            NOK         kr        150 kr
# 3               89            NOK         kr         89 kr
# 4               50            NOK         kr         50 kr
# ...            ...            ...        ...           ...
# 7898        145000            NOK         kr     145000 kr
# 7899        148000            NOK         kr     148000 kr
# 7900        150000            NOK         kr     150000 kr
# 7901        159000            NOK         kr     159000 kr
# 7902        395000            NOK         kr     395000 kr
#
#                                               image_url  \
# 0     https://images.finncdn.no/dynamic/default/item...
# 1     https://images.finncdn.no/dynamic/default/2016...
# 2     https://images.finncdn.no/dynamic/default/item...
# 3     https://images.finncdn.no/dynamic/default/item...
# 4     https://images.finncdn.no/dynamic/default/item...
# ...                                                 ...
# 7898  https://images.finncdn.no/dynamic/default/item...
# 7899  https://images.finncdn.no/dynamic/default/item...
# 7900  https://images.finncdn.no/dynamic/default/item...
# 7901  https://images.finncdn.no/dynamic/default/2023...
# 7902  https://images.finncdn.no/dynamic/default/item...
#
#                       timestamp
# 0     2025-12-11T15:58:13+00:00
# 1     2025-12-06T09:24:00+00:00
# 2     2025-12-11T19:15:38+00:00
# 3     2025-12-11T15:41:21+00:00
# 4     2025-12-11T09:58:07+00:00
# ...                         ...
# 7898  2025-11-07T10:23:07+00:00
# 7899  2025-11-01T17:38:34+00:00
# 7900  2025-10-30T23:21:51+00:00
# 7901  2025-10-20T11:23:15+00:00
# 7902  2025-12-08T12:22:01+00:00
#
# [7903 rows x 10 columns]

# %%
df_test
# Out:
#               id                                           title  \
# 0      439671551                                           Gitar
# 1      410765430        JULEGAVETIPS! Morgan W104 Akustisk Gitar
# 2      440127875       Epiphone SG Special Elektrisk gitar svart
# 3      440121961                         Cataluna akustisk gitar
# 4      440118856                                           Gitar
# ...          ...                                             ...
# 2647   378306976                 Samick Greg Bennett JZ3 LaSalle
# 2648   427067102         G#/G sharp OF-1 utgave med vib. system.
# 2649   293781545                           Fender bassbreaker 45
# 7949   438828230                    Squire Mini Stratocaster 3/4
# 28243  440128604  Nydelig og praktisk talt ubrukt PRS 509 selges
#
#                                                      url        location  \
# 0      https://www.finn.no/recommerce/forsale/item/43...       Trondheim
# 1      https://www.finn.no/bap/webstore/ad.html?finnk...         Ålesund
# 2      https://www.finn.no/recommerce/forsale/item/44...            Oslo
# 3      https://www.finn.no/recommerce/forsale/item/44...       Trondheim
# 4      https://www.finn.no/recommerce/forsale/item/44...  Charlottenlund
# ...                                                  ...             ...
# 2647   https://www.finn.no/recommerce/forsale/item/37...          Buvika
# 2648   https://www.finn.no/recommerce/forsale/item/42...             His
# 2649   https://www.finn.no/recommerce/forsale/item/29...            Oslo
# 7949   https://www.finn.no/recommerce/forsale/item/43...          Drøbak
# 28243  https://www.finn.no/recommerce/forsale/item/44...            Oslo
#
#        price_amount price_currency price_unit price_display  \
# 0               599            NOK         kr        599 kr
# 1              2095            NOK         kr       2095 kr
# 2              1000            NOK         kr       1000 kr
# 3              1000            NOK         kr       1000 kr
# 4               900            NOK         kr        900 kr
# ...             ...            ...        ...           ...
# 2647           6800            NOK         kr       6800 kr
# 2648           4444            NOK         kr       4444 kr
# 2649           5000            NOK         kr       5000 kr
# 7949           1400            NOK         kr       1400 kr
# 28243         42000            NOK         kr      42000 kr
#
#                                                image_url  \
# 0      https://images.finncdn.no/dynamic/default/item...
# 1      https://images.finncdn.no/dynamic/default/2025...
# 2      https://images.finncdn.no/dynamic/default/item...
# 3      https://images.finncdn.no/dynamic/default/item...
# 4      https://images.finncdn.no/dynamic/default/item...
# ...                                                  ...
# 2647   https://images.finncdn.no/dynamic/default/2024...
# 2648   https://images.finncdn.no/dynamic/default/c5/c...
# 2649   https://images.finncdn.no/dynamic/default/2023...
# 7949   https://images.finncdn.no/dynamic/default/item...
# 28243  https://images.finncdn.no/dynamic/default/item...
#
#                               timestamp
# 0             2025-12-02T20:13:58+00:00
# 1             2025-12-01T11:18:00+00:00
# 2             2025-12-02T20:04:06+00:00
# 3             2025-12-02T19:41:28+00:00
# 4             2025-12-02T19:09:54+00:00
# ...                                 ...
# 2647          2025-11-24T12:24:40+00:00
# 2648          2025-11-24T21:15:15+00:00
# 2649          2025-11-25T21:46:39+00:00
# 7949          2025-11-24T14:54:09+00:00
# 28243  2025-12-02T20:25:02.951000+00:00
#
# [2652 rows x 10 columns]

# %%
df.groupby("location").agg(
    {
        "price_amount": "mean",
        "id": "count",
    }
).sort_values("id", ascending=False)
# Out:
#                  price_amount   id
# location
# Oslo              5354.816471  425
# Bergen            7920.831325   83
# Hundeidvik         835.527027   74
# Drammen           6676.561644   73
# Kristiansand S   12155.435484   62
# ...                       ...  ...
# Sørumsand         7500.000000    1
# Søvik             1499.000000    1
# Tanem              650.000000    1
# Hordvik            650.000000    1
# Våler i Østfold    350.000000    1
#
# [512 rows x 2 columns]
