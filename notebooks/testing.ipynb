# %%
# %load_ext autoreload
# %autoreload 
# %cd ..
# Out:
# c:\Users\henri\Documents\Coding\finn-deals

# %%
import pandas as pd

# %%
df = pd.read_json('data/finn_items.jsonl', lines=True)

# %%
df
# Out:
#                                          title  price  \
# 0             HONDO H18 gitar produsert i 1981   2000
# 1                           Yamaha FSX 3 gitar  15490
# 2                                        Gitar    800
# 3     Elektrisk gitar svart med hvit pickguard    400
# 4                 Akustisk gitar med bæreveske   1000
# ...                                        ...    ...
# 5426                            ESP LTD EC-256   4500
# 5427                    Gibson ES 335 Dot 2019  29500
# 5428                         Ibanez SA360QM SA   3800
# 5429                                Retrogitar   3000
# 5430                                      Capo    129
#
#                                                    link
# 0     https://www.finn.no/recommerce/forsale/item/44...
# 1     https://www.finn.no/bap/webstore/ad.html?finnk...
# 2     https://www.finn.no/recommerce/forsale/item/44...
# 3     https://www.finn.no/recommerce/forsale/item/44...
# ...
