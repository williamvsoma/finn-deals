# %%
# %load_ext autoreload
# %autoreload 
# %cd ..
# Out:
# c:\Users\henri\Documents\Coding\finn-deals

# %%
import pandas as pd

# %%
df = pd.read_json('data/finn_listings_items.json')

# %%
df
# Out:
#         @type                                        description  \
# 0     Product                                              Gitar
# 1     Product  Burns Cobra Stratocaster type Elektrisk gitar ...
# 2     Product                              Gitar ramme gis bort.
# 3     Product                                    Dimebag gitarer
# 4     Product                                      Gitarstrenger
# ...       ...                                                ...
# 7747  Product                                             Som ny
# 7748  Product  Ny pris!!! FENDER MASTERBUILT ANDY SUMMERS TEL...
# 7749  Product  Fantastisk hovedverk av Elling Reitan på hele ...
# 7750  Product                                Martin D18 fra 1946
# 7751  Product                        Martin Custom gitar selges.
#
#                                                  offers  \
# 0     {'@type': 'Offer', 'price': '0', 'priceCurrenc...
# 1     {'@type': 'Offer', 'price': '0', 'priceCurrenc...
# ...
